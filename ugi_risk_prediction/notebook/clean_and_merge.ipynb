# %% [markdown]
# ### 0. Import libraries and import data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
from tableone import TableOne, load_dataset
import utils
import json

# %%
# Displays all the columns, does 
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 1. Load batched data
# The exported data is titled ```data_{encounter start date yy_mm_dd}_{encounter end date yy_mm_dd}.csv```

# %%
# Define directory path variable
directory = Path('./../data/')
results_directory = Path('./../results/')

# Define data filenames
datafiles_txtname = Path('./../data/all_data_files.txt')
ugica_filename = 'ugicancer_registry_clean.csv'

# Define renamed column name mapping 
colname_filename = Path('./../sql/colname_mappings.json')

# %%
# Read the cleaned cases file into a dataframe
file_path_ugica = directory / ugica_filename
df_ugica = pd.read_csv(file_path_ugica)

# %%
# Iterate through all the extracted batch csvs, read the data and concatenate into one dataframe
with open(directory / datafiles_txtname, 'r') as file:
    filenames = file.read().splitlines()
    
df_batch = []
for filename in filenames:
    df = pd.read_csv(directory / filename)
    df_batch.append(df)
    
df_batches = pd.concat(df_batch, ignore_index=True)
df_batches.shape

# %%
# Clean batched data. 

# Time since diagnosis; pylori - encounter start date

# Extract year from visit dates
df_batches['visit_start_date'] = pd.to_datetime(df_batches.visit_start_date)
df_batches['visit_year'] = df_batches.visit_start_date.dt.year

# Categorize medication use date
df_batches['PPI'] = df_batches.loc[:, 'PPI_start_date'].apply(lambda x: 1 if x else 0)
df_batches['ASA'] = df_batches.loc[:, 'ASA_start_date'].apply(lambda x: 1 if x else 0)
df_batches['NSAID'] = df_batches.loc[:, 'NSAID_start_date'].apply(lambda x: 1 if x else 0)
# Out:
# /Users/alyssachen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alyssachen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/alyssachen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/alyssachen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/alyssachen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
# Full outer join on MRN
df = pd.merge(df_batches, df_ugica, on='mrn', how='outer')
df.shape
# Out:
# (3742, 354)

# %% [markdown]
# ### Clean lab data

# %% [markdown]
# ### Create demographics table

# %%
# Read in the filename with the renamed column names
with open(colname_filename, 'r') as json_file:
    colname_dict = json.load(json_file)
    
mytable = TableOne(df, columns=columns, categorical=categorical, rename=colname_dict)
#, continuous=continuous, groupby=groupby, nonnormal=nonnormal, rename=rename, pval=False)

# %%
print(mytable.tabulate(tablefmt = "fancy_grid"))
mytable.to_csv(results_directory / 'mytable.csv')
# Out:
# ╒══════════════════════════════════════════════════════════╤═══════════════════════════════════════════╤═══════════╤══════════════╕
# │                                                          │                                           │ Missing   │ Overall      │
# ╞══════════════════════════════════════════════════════════╪═══════════════════════════════════════════╪═══════════╪══════════════╡
# │ n                                                        │                                           │           │ 3742         │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Sex, n (%)                                               │ FEMALE                                    │ 2742      │ 566 (56.6)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ MALE                                      │           │ 434 (43.4)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Age, mean (SD)                                           │                                           │ 2742      │ 57.1 (15.5)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Race, n (%)                                              │ African American                          │ 2742      │ 238 (23.8)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ American Indian or Alaska Native          │           │ 2 (0.2)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Asian Indian                              │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Bangladeshi                               │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Chinese                                   │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Dominica Islander                         │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Mixed racial group                        │           │ 10 (1.0)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Native Hawaiian or Other Pacific Islander │           │ 5 (0.5)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ No matching concept                       │           │ 256 (25.6)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Trinidadian                               │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ White                                     │           │ 484 (48.4)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Ethnicity, n (%)                                         │ Hispanic or Latino                        │ 2742      │ 126 (12.6)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ No matching concept                       │           │ 185 (18.5)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Not Hispanic or Latino                    │           │ 689 (68.9)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Preferred Language, n (%)                                │ Chinese (Other)                           │ 2742      │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ English                                   │           │ 918 (91.8)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Italian                                   │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Need to Collect                           │           │ 3 (0.3)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Polish                                    │           │ 4 (0.4)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Russian                                   │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Sign Language                             │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Spanish                                   │           │ 71 (7.1)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Social - Language, n (%)                                 │ Chinese (Other)                           │ 2742      │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ English                                   │           │ 918 (91.8)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Italian                                   │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Need to Collect                           │           │ 3 (0.3)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Polish                                    │           │ 4 (0.4)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Russian                                   │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Sign Language                             │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Spanish                                   │           │ 71 (7.1)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Social - Race, n (%)                                     │ ASIAN INDIAN                              │ 2742      │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ African American                          │           │ 199 (19.9)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ American Indian or Alaska Native          │           │ 2 (0.2)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Asian                                     │           │ 2 (0.2)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Asian (Pacific Islander)                  │           │ 3 (0.3)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Bangladeshi                               │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Black or African American                 │           │ 49 (4.9)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ CHINESE                                   │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Dominica Islander                         │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Hispanic or Latino                        │           │ 91 (9.1)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Hispanic/Latino                           │           │ 3 (0.3)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ OTHER                                     │           │ 116 (11.6)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Race                                      │           │ 20 (2.0)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ TRINIDADIAN                               │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ UNKNOWN                                   │           │ 35 (3.5)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ WHITE                                     │           │ 263 (26.3)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ White                                     │           │ 212 (21.2)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Social - Ethnicity, n (%)                                │ ARGENTINEAN                               │ 2742      │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Asian                                     │           │ 2 (0.2)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Black or African American                 │           │ 201 (20.1)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ CHILEAN                                   │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ COSTA RICAN                               │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ CUBAN                                     │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Central American                          │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Colombian                                 │           │ 3 (0.3)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ DOMINICAN                                 │           │ 4 (0.4)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Dominican                                 │           │ 7 (0.7)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Ecuadorian                                │           │ 4 (0.4)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ HONDURAN                                  │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Hispanic or Latino                        │           │ 80 (8.0)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ LATIN AMERICAN                            │           │ 4 (0.4)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Latin American                            │           │ 1 (0.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ NON-HISPANIC                              │           │ 489 (48.9)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Native Hawaiian or Other Pacific Islander │           │ 3 (0.3)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Not Hispanic or Latino                    │           │ 4 (0.4)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Other Race                                │           │ 30 (3.0)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ PUERTO RICAN                              │           │ 3 (0.3)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Puerto Rican                              │           │ 9 (0.9)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ Race                                      │           │ 16 (1.6)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ SALVADORAN                                │           │ 5 (0.5)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ UNKNOWN                                   │           │ 129 (12.9)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Social - Alcohol Use, n (%)                              │ -1.0                                      │ 2755      │ 26 (2.6)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 0.0                                       │           │ 423 (42.9)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 2.0                                       │           │ 538 (54.5)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Social - Smoking History, n (%)                          │ -1.0                                      │ 2742      │ 12 (1.2)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 0.0                                       │           │ 47 (4.7)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.0                                       │           │ 941 (94.1)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Social - Prior smoker, n (%)                             │ 1.0                                       │ 3026      │ 716 (100.0)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ Social - Cigarettes smoked current (pack per day), n (%) │ 0.0                                       │ 3290      │ 1 (0.2)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 0.1                                       │           │ 10 (2.2)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 0.2                                       │           │ 50 (11.1)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 0.25                                      │           │ 27 (6.0)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 0.3                                       │           │ 10 (2.2)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 0.5                                       │           │ 119 (26.3)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 0.8                                       │           │ 2 (0.4)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.0                                       │           │ 149 (33.0)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.5                                       │           │ 23 (5.1)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.75                                      │           │ 1 (0.2)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 2.0                                       │           │ 43 (9.5)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 2.5                                       │           │ 5 (1.1)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 20.0                                      │           │ 1 (0.2)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 3.0                                       │           │ 11 (2.4)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ visit_year, mean (SD)                                    │                                           │ 2742      │ 2012.0 (0.0) │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ BMI_baseline, mean (SD)                                  │                                           │ 2996      │ 66.0 (771.5) │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ BMI_prior, mean (SD)                                     │                                           │ 3235      │ 31.0 (10.9)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hgball_baseline, mean (SD)                               │                                           │ 3253      │ 12.6 (1.9)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hgball_prior, mean (SD)                                  │                                           │ 3368      │ 12.8 (1.7)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hgb_baseline, mean (SD)                                  │                                           │ 3253      │ 12.6 (1.9)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hgb_prior, mean (SD)                                     │                                           │ 3370      │ 12.8 (1.7)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ mcv_baseline, mean (SD)                                  │                                           │ 3253      │ 89.1 (7.1)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ mcv_prior, mean (SD)                                     │                                           │ 3369      │ 89.5 (7.3)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ wbc_baseline, mean (SD)                                  │                                           │ 3253      │ 7.2 (2.3)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ wbc_prior, mean (SD)                                     │                                           │ 3369      │ 7.5 (3.1)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ plt_baseline, mean (SD)                                  │                                           │ 3257      │ 233.3 (95.1) │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ plt_prior, mean (SD)                                     │                                           │ 3372      │ 239.9 (87.7) │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ sodium_baseline, mean (SD)                               │                                           │ 3139      │ 139.5 (2.9)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ sodium_prior, mean (SD)                                  │                                           │ 3283      │ 139.5 (2.8)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ potassium_baseline, mean (SD)                            │                                           │ 3139      │ 4.2 (0.4)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ potassium_prior, mean (SD)                               │                                           │ 3282      │ 4.2 (0.5)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ chloride_baseline, mean (SD)                             │                                           │ 3141      │ 102.0 (3.4)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ chloride_prior, mean (SD)                                │                                           │ 3284      │ 101.7 (3.0)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ bicarbonate_baseline, mean (SD)                          │                                           │ 3636      │ 28.5 (4.1)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ bicarbonate_prior, mean (SD)                             │                                           │ 3653      │ 28.8 (4.1)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ bun_baseline, mean (SD)                                  │                                           │ 3136      │ 18.9 (11.7)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ bun_prior, mean (SD)                                     │                                           │ 3282      │ 18.4 (9.9)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ scr_baseline, mean (SD)                                  │                                           │ 3136      │ 1.2 (1.1)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ scr_prior, mean (SD)                                     │                                           │ 3282      │ 1.2 (1.1)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ magnesium_baseline, mean (SD)                            │                                           │ 3594      │ 1.9 (0.2)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ magnesium_prior, mean (SD)                               │                                           │ 3644      │ 1.9 (0.2)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ calcium_baseline, mean (SD)                              │                                           │ 3151      │ 9.3 (0.6)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ calcium_prior, mean (SD)                                 │                                           │ 3306      │ 9.6 (0.6)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ phosphate_baseline, mean (SD)                            │                                           │ 3592      │ 3.5 (0.7)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ phosphate_prior, mean (SD)                               │                                           │ 3628      │ 3.5 (0.7)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ ast_baseline, mean (SD)                                  │                                           │ 3209      │ 28.5 (31.7)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ ast_prior, mean (SD)                                     │                                           │ 3378      │ 27.1 (23.3)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ alt_baseline, mean (SD)                                  │                                           │ 3209      │ 25.9 (29.2)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ alt_prior, mean (SD)                                     │                                           │ 3374      │ 25.8 (24.4)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ alp_baseline, mean (SD)                                  │                                           │ 3218      │ 86.8 (54.1)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ alp_prior, mean (SD)                                     │                                           │ 3377      │ 91.8 (91.7)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ tbili_baseline, mean (SD)                                │                                           │ 3218      │ 0.5 (0.6)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ tbili_prior, mean (SD)                                   │                                           │ 3378      │ 0.5 (0.3)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ tprotein_baseline, mean (SD)                             │                                           │ 3221      │ 7.1 (0.6)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ tprotein_prior, mean (SD)                                │                                           │ 3380      │ 7.2 (0.7)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ albumin_baseline, mean (SD)                              │                                           │ 3218      │ 4.1 (0.5)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ albumin_prior, mean (SD)                                 │                                           │ 3379      │ 4.2 (0.5)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ tsh_baseline, mean (SD)                                  │                                           │ 3518      │ 2.1 (4.1)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ tsh_prior, mean (SD)                                     │                                           │ 3538      │ 2.1 (2.8)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ vitD_baseline, mean (SD)                                 │                                           │ 3567      │ 30.4 (14.1)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ vitD_prior, mean (SD)                                    │                                           │ 3607      │ 33.2 (16.6)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ triglycerides_baseline, mean (SD)                        │                                           │ 3340      │ 148.2 (78.6) │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ triglycerides_prior, mean (SD)                           │                                           │ 3419      │ 136.6 (82.4) │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ LDL_baseline, mean (SD)                                  │                                           │ 3346      │ 100.9 (38.0) │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ LDL_prior, mean (SD)                                     │                                           │ 3426      │ 105.5 (44.5) │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hgba1c_baseline, mean (SD)                               │                                           │ 3395      │ 7.4 (2.0)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hgba1c_prior, mean (SD)                                  │                                           │ 3449      │ 7.4 (1.9)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hpylori_earliest_result_num, mean (SD)                   │                                           │ 3738      │ 0.0 (0.0)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hpylori_earliest_test, n (%)                             │ breath                                    │ 3738      │ 3 (75.0)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ stool                                     │           │ 1 (25.0)     │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hpylori_stool_value, n (%)                               │ Negative                                  │ 3741      │ 1 (100.0)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hpylori_iga_value, mean (SD)                             │                                           │ 3742      │ nan (nan)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hpylori_igm_value, mean (SD)                             │                                           │ 3742      │ nan (nan)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hpylori_igg_value, mean (SD)                             │                                           │ 3742      │ nan (nan)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hpylori_breath_value, n (%)                              │ Negative                                  │ 3739      │ 3 (100.0)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hnca, n (%)                                              │ 1.0                                       │ 3740      │ 2 (100.0)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ pud, n (%)                                               │ 1.0                                       │ 3711      │ 31 (100.0)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ gerd, n (%)                                              │ 1.0                                       │ 3395      │ 347 (100.0)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ hpylori, n (%)                                           │ 1.0                                       │ 3711      │ 31 (100.0)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ cad, n (%)                                               │ 1.0                                       │ 3579      │ 163 (100.0)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ tobacco, n (%)                                           │ 1.0                                       │ 3558      │ 184 (100.0)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ alcohol, n (%)                                           │ 1.0                                       │ 3711      │ 31 (100.0)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ famhx_cancer, n (%)                                      │ 0.0                                       │ 2822      │ 334 (36.3)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.0                                       │           │ 586 (63.7)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ famhx_esophagealca, n (%)                                │ 0.0                                       │ 2822      │ 920 (100.0)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ famhx_gastricca, n (%)                                   │ 0.0                                       │ 2822      │ 911 (99.0)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.0                                       │           │ 9 (1.0)      │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ famhx_colonca, n (%)                                     │ 0.0                                       │ 2822      │ 729 (79.2)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.0                                       │           │ 191 (20.8)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ PPI, mean (SD)                                           │                                           │ 2742      │ 1.0 (0.0)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ ASA, mean (SD)                                           │                                           │ 2742      │ 1.0 (0.0)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ NSAID, mean (SD)                                         │                                           │ 2742      │ 1.0 (0.0)    │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ primary_tumor_site, n (%)                                │ esophagus                                 │ 998       │ 476 (17.3)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ small intestine                           │           │ 671 (24.5)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ stomach                                   │           │ 1597 (58.2)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ ugica_stomach, n (%)                                     │ 0.0                                       │ 998       │ 1147 (41.8)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.0                                       │           │ 1597 (58.2)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ ugica_smallintestine, n (%)                              │ 0.0                                       │ 998       │ 2073 (75.5)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.0                                       │           │ 671 (24.5)   │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │ ugica_esophagus, n (%)                                   │ 0.0                                       │ 998       │ 2268 (82.7)  │
# ├──────────────────────────────────────────────────────────┼───────────────────────────────────────────┼───────────┼──────────────┤
# │                                                          │ 1.0                                       │           │ 476 (17.3)   │
# ╘══════════════════════════════════════════════════════════╧═══════════════════════════════════════════╧═══════════╧══════════════╛
